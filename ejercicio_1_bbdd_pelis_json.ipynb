# %% [markdown]
# # EVALUACIÓN FINAL MÓDULO 2
# Este script realiza el proceso completo:
# 1. Fase 1: Extracción de 100 registros desde API y limpieza de DataFrame.
# 2. Fase 2: Creación de la base de datos 'adalab_pelis_json' mediante Python.
# 3. Fase 3: Inserción de datos.
# 4. Fase 4: Consultas.

# %%
# Requisito previo: Instalación de librerías necesarias
# pip install requests / mysql-connector-python / pandas

import requests 
import mysql.connector 
import pandas as pd

# %% [markdown]
# ## FASE 1: Extracción y transformación

# %%
url_pelis_adalab = "https://beta.adalab.es/resources/apis/pelis/pelis.json"

peticion = requests.get(url_pelis_adalab) # Petición a la API

# %%
if peticion.status_code == 200: # Verificamos si la conexión ha sido exitosa (status 200 = ok)
        print("Conexión API exitosa.")
        datos_iniciales = peticion.json()
else: # Si algo falla, que nos devuelva el código para buscar la explicación del fallo
        print(f"Error al conectar con la API: {peticion.status_code}")
# Out:
# Conexión API exitosa.

# %%
if len(datos_iniciales) > 0: # Vemos cuántos registros tenemos y las claves del primero para saber qué podemos encontrar en la bbdd
        print(f"Registros totales detectados: {len(datos_iniciales)}")
        print("Claves del primer registro:", datos_iniciales[0].keys())
# Out:
# Registros totales detectados: 100
# Claves del primer registro: dict_keys(['id', 'titulo', 'año', 'duracion', 'genero', 'adultos', 'subtitulos'])

# %%
# Aunque nos piden extraer 100 registros, que son los que hay, limitamos datos para evitar sobrecarga si la API crece
limite = 100 
datos_limitados = datos_iniciales[:limite] # Cogiendo del inicio al limite marcado

# %%
display(datos_limitados) # Visualización rápida de los datos
# Out:
# [{'id': 1,
#   'titulo': 'The Godfather',
#   'año': 1972,
#   'duracion': 175,
#   'genero': 'Crimen',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 2,
#   'titulo': 'The Godfather Part II',
#   'año': 1974,
#   'duracion': 202,
#   'genero': 'Crimen',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 3,
#   'titulo': 'Pulp Fiction',
#   'año': 1994,
#   'duracion': 154,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 4,
#   'titulo': 'Forrest Gump',
#   'año': 1994,
#   'duracion': 142,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 5,
#   'titulo': 'The Dark Knight',
#   'año': 2008,
#   'duracion': 152,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 6,
#   'titulo': 'Fight Club',
#   'año': 1999,
#   'duracion': 139,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 7,
#   'titulo': 'Inception',
#   'año': 2010,
#   'duracion': 148,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'de']},
#  {'id': 8,
#   'titulo': 'The Matrix',
#   'año': 1999,
#   'duracion': 136,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 9,
#   'titulo': 'The Shawshank Redemption',
#   'año': 1994,
#   'duracion': 142,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 10,
#   'titulo': 'Interstellar',
#   'año': 2014,
#   'duracion': 169,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 11,
#   'titulo': 'Gladiator',
#   'año': 2000,
#   'duracion': 155,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 12,
#   'titulo': 'Titanic',
#   'año': 1997,
#   'duracion': 195,
#   'genero': 'Romance',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 13,
#   'titulo': 'Avatar',
#   'año': 2009,
#   'duracion': 162,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 14,
#   'titulo': 'Saving Private Ryan',
#   'año': 1998,
#   'duracion': 169,
#   'genero': 'Bélico',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 15,
#   'titulo': 'The Silence of the Lambs',
#   'año': 1991,
#   'duracion': 118,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 16,
#   'titulo': 'Se7en',
#   'año': 1995,
#   'duracion': 127,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 17,
#   'titulo': 'Goodfellas',
#   'año': 1990,
#   'duracion': 146,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 18,
#   'titulo': 'The Departed',
#   'año': 2006,
#   'duracion': 151,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 19,
#   'titulo': 'Whiplash',
#   'año': 2014,
#   'duracion': 106,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 20,
#   'titulo': 'La La Land',
#   'año': 2016,
#   'duracion': 128,
#   'genero': 'Musical',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 21,
#   'titulo': 'The Lord of the Rings: The Fellowship of the Ring',
#   'año': 2001,
#   'duracion': 178,
#   'genero': 'Fantasía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 22,
#   'titulo': 'The Lord of the Rings: The Two Towers',
#   'año': 2002,
#   'duracion': 179,
#   'genero': 'Fantasía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 23,
#   'titulo': 'The Lord of the Rings: The Return of the King',
#   'año': 2003,
#   'duracion': 201,
#   'genero': 'Fantasía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 24,
#   'titulo': 'Star Wars: A New Hope',
#   'año': 1977,
#   'duracion': 121,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 25,
#   'titulo': 'Star Wars: The Empire Strikes Back',
#   'año': 1980,
#   'duracion': 124,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 26,
#   'titulo': 'Star Wars: Return of the Jedi',
#   'año': 1983,
#   'duracion': 131,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 27,
#   'titulo': 'Back to the Future',
#   'año': 1985,
#   'duracion': 116,
#   'genero': 'Aventura',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 28,
#   'titulo': 'Jurassic Park',
#   'año': 1993,
#   'duracion': 127,
#   'genero': 'Aventura',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 29,
#   'titulo': 'The Lion King',
#   'año': 1994,
#   'duracion': 88,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 30,
#   'titulo': 'Toy Story',
#   'año': 1995,
#   'duracion': 81,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 31,
#   'titulo': 'Finding Nemo',
#   'año': 2003,
#   'duracion': 100,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 32,
#   'titulo': 'Shrek',
#   'año': 2001,
#   'duracion': 90,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 33,
#   'titulo': 'The Incredibles',
#   'año': 2004,
#   'duracion': 115,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 34,
#   'titulo': 'WALL·E',
#   'año': 2008,
#   'duracion': 98,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 35,
#   'titulo': 'Up',
#   'año': 2009,
#   'duracion': 96,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 36,
#   'titulo': 'Spirited Away',
#   'año': 2001,
#   'duracion': 125,
#   'genero': 'Animación',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'jp']},
#  {'id': 37,
#   'titulo': 'Princess Mononoke',
#   'año': 1997,
#   'duracion': 134,
#   'genero': 'Animación',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'jp']},
#  {'id': 38,
#   'titulo': 'The Green Mile',
#   'año': 1999,
#   'duracion': 189,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 39,
#   'titulo': 'The Truman Show',
#   'año': 1998,
#   'duracion': 103,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 40,
#   'titulo': 'The Social Network',
#   'año': 2010,
#   'duracion': 120,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 41,
#   'titulo': 'Joker',
#   'año': 2019,
#   'duracion': 122,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 42,
#   'titulo': 'Black Panther',
#   'año': 2018,
#   'duracion': 134,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 43,
#   'titulo': 'Iron Man',
#   'año': 2008,
#   'duracion': 126,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 44,
#   'titulo': 'The Avengers',
#   'año': 2012,
#   'duracion': 143,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 45,
#   'titulo': 'Avengers: Endgame',
#   'año': 2019,
#   'duracion': 181,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 46,
#   'titulo': 'Dune',
#   'año': 2021,
#   'duracion': 155,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 47,
#   'titulo': 'Mad Max: Fury Road',
#   'año': 2015,
#   'duracion': 120,
#   'genero': 'Acción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 48,
#   'titulo': 'The Revenant',
#   'año': 2015,
#   'duracion': 156,
#   'genero': 'Aventura',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 49,
#   'titulo': 'Parasite',
#   'año': 2019,
#   'duracion': 132,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'ko']},
#  {'id': 50,
#   'titulo': 'Oldboy',
#   'año': 2003,
#   'duracion': 120,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'ko']},
#  {'id': 51,
#   'titulo': 'The Pianist',
#   'año': 2002,
#   'duracion': 150,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 52,
#   'titulo': 'The Wolf of Wall Street',
#   'año': 2013,
#   'duracion': 180,
#   'genero': 'Biografía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 53,
#   'titulo': 'Her',
#   'año': 2013,
#   'duracion': 126,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 54,
#   'titulo': 'Gravity',
#   'año': 2013,
#   'duracion': 91,
#   'genero': 'Ciencia ficción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 55,
#   'titulo': 'The Shape of Water',
#   'año': 2017,
#   'duracion': 123,
#   'genero': 'Fantasía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 56,
#   'titulo': 'Get Out',
#   'año': 2017,
#   'duracion': 104,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 57,
#   'titulo': 'It',
#   'año': 2017,
#   'duracion': 135,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 58,
#   'titulo': 'The Conjuring',
#   'año': 2013,
#   'duracion': 112,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 59,
#   'titulo': 'A Quiet Place',
#   'año': 2018,
#   'duracion': 90,
#   'genero': 'Terror',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 60,
#   'titulo': 'The Exorcist',
#   'año': 1973,
#   'duracion': 122,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 61,
#   'titulo': 'The Shining',
#   'año': 1980,
#   'duracion': 144,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 62,
#   'titulo': 'Blade Runner',
#   'año': 1982,
#   'duracion': 117,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 63,
#   'titulo': 'Blade Runner 2049',
#   'año': 2017,
#   'duracion': 164,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 64,
#   'titulo': 'Alien',
#   'año': 1979,
#   'duracion': 117,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 65,
#   'titulo': 'Aliens',
#   'año': 1986,
#   'duracion': 137,
#   'genero': 'Ciencia ficción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 66,
#   'titulo': 'The Terminator',
#   'año': 1984,
#   'duracion': 107,
#   'genero': 'Acción',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 67,
#   'titulo': 'Terminator 2: Judgment Day',
#   'año': 1991,
#   'duracion': 137,
#   'genero': 'Acción',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 68,
#   'titulo': 'Rocky',
#   'año': 1976,
#   'duracion': 120,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 69,
#   'titulo': 'Raging Bull',
#   'año': 1980,
#   'duracion': 129,
#   'genero': 'Biografía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 70,
#   'titulo': 'Taxi Driver',
#   'año': 1976,
#   'duracion': 113,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 71,
#   'titulo': 'Casablanca',
#   'año': 1942,
#   'duracion': 102,
#   'genero': 'Romance',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 72,
#   'titulo': 'Citizen Kane',
#   'año': 1941,
#   'duracion': 119,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 73,
#   'titulo': 'Psycho',
#   'año': 1960,
#   'duracion': 109,
#   'genero': 'Terror',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 74,
#   'titulo': 'Vertigo',
#   'año': 1958,
#   'duracion': 128,
#   'genero': 'Suspense',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 75,
#   'titulo': 'Rear Window',
#   'año': 1954,
#   'duracion': 112,
#   'genero': 'Suspense',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 76,
#   'titulo': '12 Angry Men',
#   'año': 1957,
#   'duracion': 96,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 77,
#   'titulo': "Schindler's List",
#   'año': 1993,
#   'duracion': 195,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 78,
#   'titulo': 'American Beauty',
#   'año': 1999,
#   'duracion': 122,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 79,
#   'titulo': 'No Country for Old Men',
#   'año': 2007,
#   'duracion': 122,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 80,
#   'titulo': 'The Big Lebowski',
#   'año': 1998,
#   'duracion': 117,
#   'genero': 'Comedia',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 81,
#   'titulo': 'Amélie',
#   'año': 2001,
#   'duracion': 122,
#   'genero': 'Romance',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 82,
#   'titulo': 'The Intouchables',
#   'año': 2011,
#   'duracion': 112,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'fr']},
#  {'id': 83,
#   'titulo': 'City of God',
#   'año': 2002,
#   'duracion': 130,
#   'genero': 'Crimen',
#   'adultos': True,
#   'subtitulos': ['es', 'en', 'pt']},
#  {'id': 84,
#   'titulo': "Pan's Labyrinth",
#   'año': 2006,
#   'duracion': 118,
#   'genero': 'Fantasía',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 85,
#   'titulo': 'Roma',
#   'año': 2018,
#   'duracion': 135,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 86,
#   'titulo': 'Slumdog Millionaire',
#   'año': 2008,
#   'duracion': 120,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 87,
#   'titulo': 'Million Dollar Baby',
#   'año': 2004,
#   'duracion': 132,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 88,
#   'titulo': "The King's Speech",
#   'año': 2010,
#   'duracion': 118,
#   'genero': 'Biografía',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 89,
#   'titulo': 'Argo',
#   'año': 2012,
#   'duracion': 120,
#   'genero': 'Thriller',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 90,
#   'titulo': 'Moonlight',
#   'año': 2016,
#   'duracion': 111,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 91,
#   'titulo': 'Manchester by the Sea',
#   'año': 2016,
#   'duracion': 137,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 92,
#   'titulo': 'Birdman',
#   'año': 2014,
#   'duracion': 119,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 93,
#   'titulo': 'Django Unchained',
#   'año': 2012,
#   'duracion': 165,
#   'genero': 'Western',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 94,
#   'titulo': 'Inglourious Basterds',
#   'año': 2009,
#   'duracion': 153,
#   'genero': 'Bélico',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 95,
#   'titulo': 'The Hateful Eight',
#   'año': 2015,
#   'duracion': 168,
#   'genero': 'Western',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 96,
#   'titulo': 'La vita è bella',
#   'año': 1997,
#   'duracion': 116,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en', 'it']},
#  {'id': 97,
#   'titulo': 'Requiem for a Dream',
#   'año': 2000,
#   'duracion': 102,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 98,
#   'titulo': 'Memento',
#   'año': 2000,
#   'duracion': 113,
#   'genero': 'Thriller',
#   'adultos': True,
#   'subtitulos': ['es', 'en']},
#  {'id': 99,
#   'titulo': 'Eternal Sunshine of the Spotless Mind',
#   'año': 2004,
#   'duracion': 108,
#   'genero': 'Drama',
#   'adultos': False,
#   'subtitulos': ['es', 'en']},
#  {'id': 100,
#   'titulo': 'Donnie Darko',
#   'año': 2001,
#   'duracion': 113,
#   'genero': 'Drama',
#   'adultos': True,
#   'subtitulos': ['es', 'en']}]

# %%
lista_peliculas = [] # Creamos una lista vacía y vamos añadiendo diccionarios completos (filas) en cada iteración.

for peli in datos_limitados: # NO incluimos 'subtitulos' en este diccionario para simular que, en este punto del proyecto, ese dato no nos interesaba.
        nueva_peli = {
            'Titulo': peli.get('titulo', 'desconocido'), # Si no hay título, ponemos 'Desconocido' para evitar vacíos
            'Año': peli.get('año', 0), # Si no hay año, ponemos 0 para evitar vacíos
            'Duracion': peli.get('duracion', 0),
            'Genero': peli.get('genero', 'sin clasificar'),
            'Contenido adulto': peli.get('adultos', False) 
         }
        lista_peliculas.append(nueva_peli)  # Añadimos la película procesada a la lista

# %%
df_peliculas = pd.DataFrame(lista_peliculas)
print("DataFrame creado correctamente (datos sin subtítulos).")
pd.DataFrame(lista_peliculas)
# Out:
# DataFrame creado correctamente (datos sin subtítulos).
#                          Titulo                         Año  Duracion      Genero       Contenido adulto
# 0                                       The Godfather  1972     175             Crimen        False
# 1                               The Godfather Part II  1974     202             Crimen        False
# 2                                        Pulp Fiction  1994     154             Crimen         True
# 3                                        Forrest Gump  1994     142              Drama        False
# 4                                     The Dark Knight  2008     152             Acción        False
# 5                                          Fight Club  1999     139              Drama         True
# 6                                           Inception  2010     148    Ciencia ficción        False
# 7                                          The Matrix  1999     136    Ciencia ficción        False
# 8                            The Shawshank Redemption  1994     142              Drama        False
# 9                                        Interstellar  2014     169    Ciencia ficción        False
# 10                                          Gladiator  2000     155             Acción        False
# 11                                            Titanic  1997     195            Romance        False
# 12                                             Avatar  2009     162    Ciencia ficción        False
# 13                                Saving Private Ryan  1998     169             Bélico         True
# 14                           The Silence of the Lambs  1991     118           Thriller         True
# 15                                              Se7en  1995     127           Thriller         True
# 16                                         Goodfellas  1990     146             Crimen         True
# 17                                       The Departed  2006     151             Crimen         True
# 18                                           Whiplash  2014     106              Drama        False
# 19                                         La La Land  2016     128            Musical        False
# 20  The Lord of the Rings: The Fellowship of the Ring  2001     178           Fantasía        False
# 21              The Lord of the Rings: The Two Towers  2002     179           Fantasía        False
# 22      The Lord of the Rings: The Return of the King  2003     201           Fantasía        False
# 23                              Star Wars: A New Hope  1977     121    Ciencia ficción        False
# 24                 Star Wars: The Empire Strikes Back  1980     124    Ciencia ficción        False
# 25                      Star Wars: Return of the Jedi  1983     131    Ciencia ficción        False
# 26                                 Back to the Future  1985     116           Aventura        False
# 27                                      Jurassic Park  1993     127           Aventura        False
# 28                                      The Lion King  1994      88          Animación        False
# 29                                          Toy Story  1995      81          Animación        False
# 30                                       Finding Nemo  2003     100          Animación        False
# 31                                              Shrek  2001      90          Animación        False
# 32                                    The Incredibles  2004     115          Animación        False
# 33                                             WALL·E  2008      98          Animación        False
# 34                                                 Up  2009      96          Animación        False
# 35                                      Spirited Away  2001     125          Animación        False
# 36                                  Princess Mononoke  1997     134          Animación         True
# 37                                     The Green Mile  1999     189              Drama         True
# 38                                    The Truman Show  1998     103              Drama        False
# 39                                 The Social Network  2010     120              Drama        False
# 40                                              Joker  2019     122              Drama         True
# 41                                      Black Panther  2018     134             Acción        False
# 42                                           Iron Man  2008     126             Acción        False
# 43                                       The Avengers  2012     143             Acción        False
# 44                                  Avengers: Endgame  2019     181             Acción        False
# 45                                               Dune  2021     155    Ciencia ficción        False
# 46                                 Mad Max: Fury Road  2015     120             Acción         True
# 47                                       The Revenant  2015     156           Aventura         True
# 48                                           Parasite  2019     132           Thriller         True
# 49                                             Oldboy  2003     120           Thriller         True
# 50                                        The Pianist  2002     150              Drama         True
# 51                            The Wolf of Wall Street  2013     180          Biografía         True
# 52                                                Her  2013     126              Drama        False
# 53                                            Gravity  2013      91    Ciencia ficción        False
# 54                                 The Shape of Water  2017     123           Fantasía         True
# 55                                            Get Out  2017     104             Terror         True
# 56                                                 It  2017     135             Terror         True
# 57                                      The Conjuring  2013     112             Terror         True
# 58                                      A Quiet Place  2018      90             Terror        False
# 59                                       The Exorcist  1973     122             Terror         True
# 60                                        The Shining  1980     144             Terror         True
# 61                                       Blade Runner  1982     117    Ciencia ficción         True
# 62                                  Blade Runner 2049  2017     164    Ciencia ficción         True
# 63                                              Alien  1979     117    Ciencia ficción         True
# 64                                             Aliens  1986     137    Ciencia ficción         True
# 65                                     The Terminator  1984     107             Acción         True
# 66                         Terminator 2: Judgment Day  1991     137             Acción        False
# 67                                              Rocky  1976     120              Drama        False
# 68                                        Raging Bull  1980     129          Biografía         True
# 69                                        Taxi Driver  1976     113              Drama         True
# 70                                         Casablanca  1942     102            Romance        False
# 71                                       Citizen Kane  1941     119              Drama        False
# 72                                             Psycho  1960     109             Terror         True
# 73                                            Vertigo  1958     128           Suspense        False
# 74                                        Rear Window  1954     112           Suspense        False
# 75                                       12 Angry Men  1957      96              Drama        False
# 76                                   Schindler's List  1993     195              Drama         True
# 77                                    American Beauty  1999     122              Drama         True
# 78                             No Country for Old Men  2007     122             Crimen         True
# 79                                   The Big Lebowski  1998     117            Comedia         True
# 80                                             Amélie  2001     122            Romance        False
# 81                                   The Intouchables  2011     112              Drama        False
# 82                                        City of God  2002     130             Crimen         True
# 83                                    Pan's Labyrinth  2006     118           Fantasía         True
# 84                                               Roma  2018     135              Drama         True
# 85                                Slumdog Millionaire  2008     120              Drama        False
# 86                                Million Dollar Baby  2004     132              Drama         True
# 87                                  The King's Speech  2010     118          Biografía        False
# 88                                               Argo  2012     120           Thriller        False
# 89                                          Moonlight  2016     111              Drama         True
# 90                              Manchester by the Sea  2016     137              Drama         True
# 91                                            Birdman  2014     119              Drama         True
# 92                                   Django Unchained  2012     165            Western         True
# 93                               Inglourious Basterds  2009     153             Bélico         True
# 94                                  The Hateful Eight  2015     168            Western         True
# 95                                    La vita è bella  1997     116              Drama        False
# 96                                Requiem for a Dream  2000     102              Drama         True
# 97                                            Memento  2000     113           Thriller         True
# 98              Eternal Sunshine of the Spotless Mind  2004     108              Drama        False
# 99                                       Donnie Darko  2001     113              Drama         True

# %%
# AJUSTES VISUALES : 
df_peliculas.index = range(1, len(df_peliculas) + 1) # Índice desde 1 (no desde 0)
pd.set_option('display.max_columns', None)  # Mostrar todas las columnas
pd.set_option('display.width', 1000)        # Ancho máximo para evitar saltos de línea
pd.set_option('display.colheader_justify', 'center') # Centrar encabezados
print(df_peliculas)
# Out:
#                           Titulo                         Año  Duracion      Genero       Contenido adulto
# 1                                        The Godfather  1972     175             Crimen        False
# 2                                The Godfather Part II  1974     202             Crimen        False
# 3                                         Pulp Fiction  1994     154             Crimen         True
# 4                                         Forrest Gump  1994     142              Drama        False
# 5                                      The Dark Knight  2008     152             Acción        False
# 6                                           Fight Club  1999     139              Drama         True
# 7                                            Inception  2010     148    Ciencia ficción        False
# 8                                           The Matrix  1999     136    Ciencia ficción        False
# 9                             The Shawshank Redemption  1994     142              Drama        False
# 10                                        Interstellar  2014     169    Ciencia ficción        False
# 11                                           Gladiator  2000     155             Acción        False
# 12                                             Titanic  1997     195            Romance        False
# 13                                              Avatar  2009     162    Ciencia ficción        False
# 14                                 Saving Private Ryan  1998     169             Bélico         True
# 15                            The Silence of the Lambs  1991     118           Thriller         True
# 16                                               Se7en  1995     127           Thriller         True
# 17                                          Goodfellas  1990     146             Crimen         True
# 18                                        The Departed  2006     151             Crimen         True
# 19                                            Whiplash  2014     106              Drama        False
# 20                                          La La Land  2016     128            Musical        False
# 21   The Lord of the Rings: The Fellowship of the Ring  2001     178           Fantasía        False
# 22               The Lord of the Rings: The Two Towers  2002     179           Fantasía        False
# 23       The Lord of the Rings: The Return of the King  2003     201           Fantasía        False
# 24                               Star Wars: A New Hope  1977     121    Ciencia ficción        False
# 25                  Star Wars: The Empire Strikes Back  1980     124    Ciencia ficción        False
# 26                       Star Wars: Return of the Jedi  1983     131    Ciencia ficción        False
# 27                                  Back to the Future  1985     116           Aventura        False
# 28                                       Jurassic Park  1993     127           Aventura        False
# 29                                       The Lion King  1994      88          Animación        False
# 30                                           Toy Story  1995      81          Animación        False
# 31                                        Finding Nemo  2003     100          Animación        False
# 32                                               Shrek  2001      90          Animación        False
# 33                                     The Incredibles  2004     115          Animación        False
# 34                                              WALL·E  2008      98          Animación        False
# 35                                                  Up  2009      96          Animación        False
# 36                                       Spirited Away  2001     125          Animación        False
# 37                                   Princess Mononoke  1997     134          Animación         True
# 38                                      The Green Mile  1999     189              Drama         True
# 39                                     The Truman Show  1998     103              Drama        False
# 40                                  The Social Network  2010     120              Drama        False
# 41                                               Joker  2019     122              Drama         True
# 42                                       Black Panther  2018     134             Acción        False
# 43                                            Iron Man  2008     126             Acción        False
# 44                                        The Avengers  2012     143             Acción        False
# 45                                   Avengers: Endgame  2019     181             Acción        False
# 46                                                Dune  2021     155    Ciencia ficción        False
# 47                                  Mad Max: Fury Road  2015     120             Acción         True
# 48                                        The Revenant  2015     156           Aventura         True
# 49                                            Parasite  2019     132           Thriller         True
# 50                                              Oldboy  2003     120           Thriller         True
# 51                                         The Pianist  2002     150              Drama         True
# 52                             The Wolf of Wall Street  2013     180          Biografía         True
# 53                                                 Her  2013     126              Drama        False
# 54                                             Gravity  2013      91    Ciencia ficción        False
# 55                                  The Shape of Water  2017     123           Fantasía         True
# 56                                             Get Out  2017     104             Terror         True
# 57                                                  It  2017     135             Terror         True
# 58                                       The Conjuring  2013     112             Terror         True
# 59                                       A Quiet Place  2018      90             Terror        False
# 60                                        The Exorcist  1973     122             Terror         True
# 61                                         The Shining  1980     144             Terror         True
# 62                                        Blade Runner  1982     117    Ciencia ficción         True
# 63                                   Blade Runner 2049  2017     164    Ciencia ficción         True
# 64                                               Alien  1979     117    Ciencia ficción         True
# 65                                              Aliens  1986     137    Ciencia ficción         True
# 66                                      The Terminator  1984     107             Acción         True
# 67                          Terminator 2: Judgment Day  1991     137             Acción        False
# 68                                               Rocky  1976     120              Drama        False
# 69                                         Raging Bull  1980     129          Biografía         True
# 70                                         Taxi Driver  1976     113              Drama         True
# 71                                          Casablanca  1942     102            Romance        False
# 72                                        Citizen Kane  1941     119              Drama        False
# 73                                              Psycho  1960     109             Terror         True
# 74                                             Vertigo  1958     128           Suspense        False
# 75                                         Rear Window  1954     112           Suspense        False
# 76                                        12 Angry Men  1957      96              Drama        False
# 77                                    Schindler's List  1993     195              Drama         True
# 78                                     American Beauty  1999     122              Drama         True
# 79                              No Country for Old Men  2007     122             Crimen         True
# 80                                    The Big Lebowski  1998     117            Comedia         True
# 81                                              Amélie  2001     122            Romance        False
# 82                                    The Intouchables  2011     112              Drama        False
# 83                                         City of God  2002     130             Crimen         True
# 84                                     Pan's Labyrinth  2006     118           Fantasía         True
# 85                                                Roma  2018     135              Drama         True
# 86                                 Slumdog Millionaire  2008     120              Drama        False
# 87                                 Million Dollar Baby  2004     132              Drama         True
# 88                                   The King's Speech  2010     118          Biografía        False
# 89                                                Argo  2012     120           Thriller        False
# 90                                           Moonlight  2016     111              Drama         True
# 91                               Manchester by the Sea  2016     137              Drama         True
# 92                                             Birdman  2014     119              Drama         True
# 93                                    Django Unchained  2012     165            Western         True
# 94                                Inglourious Basterds  2009     153             Bélico         True
# 95                                   The Hateful Eight  2015     168            Western         True
# 96                                     La vita è bella  1997     116              Drama        False
# 97                                 Requiem for a Dream  2000     102              Drama         True
# 98                                             Memento  2000     113           Thriller         True
# 99               Eternal Sunshine of the Spotless Mind  2004     108              Drama        False
# 100                                       Donnie Darko  2001     113              Drama         True

# %% [markdown]
# ## FASE 2: Creación de la base de datos

# %%
config = {
    "host": "localhost",
    "user": "root",
    "password": "", # Pon tu contraseña si tienes
    "auth_plugin": "mysql_native_password"
}
